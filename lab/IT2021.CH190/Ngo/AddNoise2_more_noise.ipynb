# %%
# pip install pydub

# %%
import os
import random
import numpy as np
from pydub import AudioSegment
from pydub.generators import WhiteNoise

# PinkNoise và BrownNoise không hỗ trợ trong pydub mặc định, tạo giả lập bằng cách lọc white noise

def generate_pink_noise(duration_ms):
    white = WhiteNoise().to_audio_segment(duration=duration_ms)
    return white.low_pass_filter(2000)  # Giả lập pink noise bằng lọc tần số thấp

def generate_brown_noise(duration_ms):
    white = WhiteNoise().to_audio_segment(duration=duration_ms)
    return white.low_pass_filter(500)  # Giả lập brown noise bằng lọc tần số thấp mạnh hơn

def generate_random_noise(duration_ms, noise_type="white"):
    """
    Sinh noise ngẫu nhiên dựa trên loại noise và độ dài.
    
    :param duration_ms: Độ dài của noise cần tạo (ms).
    :param noise_type: Loại noise (white, pink, brown).
    :return: AudioSegment chứa noise.
    """
    if noise_type == "white":
        return WhiteNoise().to_audio_segment(duration=duration_ms)
    elif noise_type == "pink":
        return generate_pink_noise(duration_ms)
    elif noise_type == "brown":
        return generate_brown_noise(duration_ms)
    else:
        return WhiteNoise().to_audio_segment(duration=duration_ms)  # Mặc định white noise

def add_noise_to_audio(original_audio_path, noise_audio_path, output_path):
    """
    Thêm nhiễu vào file audio gốc, gồm noise ngẫu nhiên và noise từ file nhỏ.
    Lưu file kết quả vào folder mới, không ghi đè.

    :param original_audio_path: Đường dẫn đến file audio gốc (mp3).
    :param noise_audio_path: Đường dẫn đến file audio nhiễu (wav).
    :param output_path: Đường dẫn lưu file kết quả (mp3).
    """
    # Load audio gốc và noise từ file nhỏ
    original_audio = AudioSegment.from_mp3(original_audio_path)
    noise_file_audio = AudioSegment.from_wav(noise_audio_path)

    # Sinh noise ngẫu nhiên với độ dài khớp audio gốc
    noise_type = random.choice(["white", "pink", "brown"])
    random_noise = generate_random_noise(len(original_audio), noise_type=noise_type)

    # Ghép noise từ file nhỏ để đủ dài
    if len(noise_file_audio) < len(original_audio):
        noise_file_audio = noise_file_audio * (len(original_audio) // len(noise_file_audio) + 1)
    noise_file_audio = noise_file_audio[:len(original_audio)]

    # Điều chỉnh âm lượng nhiễu nhỏ hơn âm gốc 1/4
    original_rms = original_audio.rms

    for noise_audio in [random_noise, noise_file_audio]:
        noise_rms = noise_audio.rms
        if noise_rms > 0:
            gain_db = 20 * np.log10(original_rms / 4 / noise_rms)
            noise_audio = noise_audio.apply_gain(gain_db)
        # Trộn vào original
        original_audio = original_audio.overlay(noise_audio)

    # Lưu file kết quả vào output_path
    original_audio.export(output_path, format="mp3")

def process_audio_lists(original_audio_folder, noise_audio_folder, output_folder):
    """
    Thêm noise ngẫu nhiên và noise từ file nhỏ vào tất cả file mp3 gốc.
    Lưu kết quả vào folder mới, không ghi đè file gốc.

    :param original_audio_folder: Thư mục chứa audio gốc.
    :param noise_audio_folder: Thư mục chứa audio nhiễu nhỏ.
    :param output_folder: Thư mục để lưu file kết quả.
    """
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    original_files = [f for f in os.listdir(original_audio_folder) if f.endswith(".mp3")]
    noise_files = [f for f in os.listdir(noise_audio_folder) if f.endswith(".wav")]

    for original_file in original_files:
        original_path = os.path.join(original_audio_folder, original_file)
        noise_file = random.choice(noise_files)
        noise_path = os.path.join(noise_audio_folder, noise_file)

        output_path = os.path.join(output_folder, original_file)
        add_noise_to_audio(original_path, noise_path, output_path)
        print(f"Processed {original_file} with noise {noise_file} -> {output_path}")

# Ví dụ sử dụng:
# process_audio_lists("path_to_original_audio", "path_to_noise_audio", "path_to_output_folder")

# %%
process_audio_lists("./SampleAudioClean/data", "./SampleAudioClean/noise", "./add_noise_output")
# Out:
# Processed FPTOpenSpeechData_Set001_V0.1_003978.mp3 with noise 1-15689-B-4.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003978.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001809.mp3 with noise 5-244315-B-6.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001809.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001821.mp3 with noise 1-19026-A-43.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001821.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003950.mp3 with noise 5-254160-A-22.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003950.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002496.mp3 with noise 5-251963-A-47.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002496.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003788.mp3 with noise 3-208820-A-49.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003788.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003944.mp3 with noise 5-263831-A-6.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003944.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002482.mp3 with noise 1-19840-A-36.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002482.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001835.mp3 with noise 1-14262-A-37.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001835.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003011.mp3 with noise 1-24076-A-43.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003011.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001606.mp3 with noise 1-12654-A-15.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001606.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001160.mp3 with noise 1-67033-A-37.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001160.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003777.mp3 with noise 5-243783-A-44.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003777.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002469.mp3 with noise 1-67033-A-37.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002469.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003763.mp3 with noise 1-64398-A-41.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003763.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001174.mp3 with noise 1-30226-A-0.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001174.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001612.mp3 with noise 1-22882-A-44.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001612.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003005.mp3 with noise 1-36393-A-23.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003005.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002333.mp3 with noise 5-250026-A-30.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002333.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003993.mp3 with noise 1-43807-A-47.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003993.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002455.mp3 with noise 1-14262-A-37.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002455.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001148.mp3 with noise 4-169127-A-41.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001148.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003987.mp3 with noise 1-24074-A-43.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003987.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002441.mp3 with noise 1-23094-B-15.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002441.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002327.mp3 with noise 1-17742-A-12.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002327.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003039.mp3 with noise 1-53467-A-47.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003039.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002870.mp3 with noise 3-208820-A-49.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002870.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002864.mp3 with noise 1-61534-A-27.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002864.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002694.mp3 with noise 1-53670-A-18.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002694.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001389.mp3 with noise 4-164859-A-1.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001389.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002858.mp3 with noise 1-29680-A-21.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002858.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002680.mp3 with noise 5-253534-A-26.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002680.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003575.mp3 with noise 1-57318-A-13.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003575.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001362.mp3 with noise 4-157297-A-21.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001362.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001404.mp3 with noise 3-197435-B-22.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001404.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003213.mp3 with noise 1-31748-A-21.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003213.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003207.mp3 with noise 1-44831-A-1.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003207.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002119.mp3 with noise 1-5996-A-6.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002119.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001410.mp3 with noise 5-251963-A-47.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001410.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001376.mp3 with noise 1-17970-A-4.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001376.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003561.mp3 with noise 4-165791-A-45.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003561.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002657.mp3 with noise 1-58277-A-3.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002657.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003549.mp3 with noise 1-47714-A-16.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003549.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002131.mp3 with noise 5-260433-A-39.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002131.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001438.mp3 with noise 1-36929-A-47.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001438.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002125.mp3 with noise 1-31482-B-42.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002125.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002643.mp3 with noise 1-58846-A-34.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002643.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002904.mp3 with noise 1-60676-A-34.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002904.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002910.mp3 with noise 1-43382-A-1.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002910.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002938.mp3 with noise 3-197435-B-22.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002938.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003398.mp3 with noise 5-260011-A-34.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003398.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002086.mp3 with noise 5-253094-D-49.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002086.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002092.mp3 with noise 4-150364-B-46.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002092.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003401.mp3 with noise 1-16568-A-3.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003401.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001216.mp3 with noise 1-19026-A-43.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001216.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001570.mp3 with noise 4-167155-A-32.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001570.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002079.mp3 with noise 1-21934-A-38.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002079.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003367.mp3 with noise 1-51036-A-16.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003367.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003373.mp3 with noise 3-188726-A-35.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003373.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001564.mp3 with noise 1-53501-A-32.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001564.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001202.mp3 with noise 1-50623-A-15.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001202.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003415.mp3 with noise 3-203375-A-39.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003415.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002723.mp3 with noise 4-149940-A-5.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002723.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002045.mp3 with noise 4-167077-A-20.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002045.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001558.mp3 with noise 1-56234-A-9.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001558.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002051.mp3 with noise 1-40730-A-1.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002051.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003429.mp3 with noise 5-256512-A-30.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003429.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002737.mp3 with noise 1-56269-A-18.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002737.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001969.mp3 with noise 5-250026-B-30.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001969.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003818.mp3 with noise 4-165933-A-45.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003818.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002284.mp3 with noise 5-243773-A-44.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002284.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001955.mp3 with noise 1-56270-A-29.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001955.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003824.mp3 with noise 1-32373-A-35.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003824.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003830.mp3 with noise 1-23222-A-19.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003830.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001941.mp3 with noise 4-167077-A-20.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001941.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001799.mp3 with noise 1-5996-A-6.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001799.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002290.mp3 with noise 1-19111-A-24.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002290.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003165.mp3 with noise 5-260011-A-34.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003165.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001772.mp3 with noise 1-59324-A-21.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001772.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001014.mp3 with noise 4-163264-A-10.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001014.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003603.mp3 with noise 5-253101-B-49.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003603.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002509.mp3 with noise 3-216280-A-39.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002509.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003617.mp3 with noise 1-21934-A-38.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003617.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001766.mp3 with noise 1-46272-A-12.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001766.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003171.mp3 with noise 1-24076-A-43.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003171.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001996.mp3 with noise 1-1791-A-26.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001996.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003159.mp3 with noise 4-156993-A-19.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003159.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002247.mp3 with noise 1-36929-A-47.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002247.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002521.mp3 with noise 1-51805-H-33.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002521.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001028.mp3 with noise 1-32373-B-35.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001028.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002535.mp3 with noise 1-17092-B-27.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002535.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002253.mp3 with noise 4-161519-A-19.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002253.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001982.mp3 with noise 5-261433-A-15.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001982.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002534.mp3 with noise 1-51805-D-33.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002534.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001983.mp3 with noise 1-43760-A-11.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001983.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002252.mp3 with noise 3-187549-B-6.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002252.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002246.mp3 with noise 1-39901-B-11.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002246.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003158.mp3 with noise 5-244526-A-26.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003158.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001997.mp3 with noise 4-164859-A-1.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001997.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001029.mp3 with noise 1-23094-B-15.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001029.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002520.mp3 with noise 1-39923-A-1.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002520.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001001.mp3 with noise 1-40154-A-46.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001001.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003616.mp3 with noise 5-243783-A-44.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003616.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002508.mp3 with noise 1-56234-A-9.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002508.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003170.mp3 with noise 5-249748-A-28.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003170.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001767.mp3 with noise 5-244310-A-25.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001767.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001773.mp3 with noise 4-164661-B-12.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001773.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003164.mp3 with noise 1-49409-B-8.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003164.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003602.mp3 with noise 1-39937-A-28.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003602.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001015.mp3 with noise 5-256452-A-5.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001015.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003831.mp3 with noise 4-165845-A-45.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003831.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002291.mp3 with noise 1-36164-B-26.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002291.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001798.mp3 with noise 5-260875-A-35.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001798.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001940.mp3 with noise 4-161127-A-10.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001940.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001954.mp3 with noise 4-161579-B-40.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001954.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002285.mp3 with noise 1-61221-A-17.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002285.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003825.mp3 with noise 1-57163-A-38.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003825.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001968.mp3 with noise 1-36164-A-26.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001968.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003819.mp3 with noise 1-40730-A-1.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003819.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002050.mp3 with noise 1-62565-A-44.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002050.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001559.mp3 with noise 1-12654-B-15.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001559.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002736.mp3 with noise 3-185456-A-29.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002736.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003428.mp3 with noise 1-67230-A-29.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003428.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002722.mp3 with noise 1-13571-A-46.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002722.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002044.mp3 with noise 4-164243-A-26.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002044.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001565.mp3 with noise 1-60997-A-20.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001565.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003372.mp3 with noise 5-260164-A-23.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003372.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003414.mp3 with noise 3-185456-A-29.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003414.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001203.mp3 with noise 1-34119-A-1.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001203.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001217.mp3 with noise 1-24796-A-47.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001217.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003400.mp3 with noise 4-164064-A-1.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003400.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003366.mp3 with noise 5-245040-A-35.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003366.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002078.mp3 with noise 1-51805-D-33.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002078.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001571.mp3 with noise 4-167063-B-11.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001571.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002093.mp3 with noise 1-24524-C-19.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002093.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002939.mp3 with noise 1-43807-B-47.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002939.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002087.mp3 with noise 1-57316-A-13.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002087.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003399.mp3 with noise 5-245040-A-35.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003399.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002911.mp3 with noise 5-259180-A-15.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002911.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002905.mp3 with noise 1-47274-A-21.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002905.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002124.mp3 with noise 4-169127-A-41.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002124.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002642.mp3 with noise 4-167642-A-21.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002642.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003548.mp3 with noise 1-61252-A-11.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003548.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002656.mp3 with noise 1-36400-A-23.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002656.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001439.mp3 with noise 1-59102-A-13.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001439.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002130.mp3 with noise 1-51035-A-16.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002130.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001411.mp3 with noise 4-163606-A-16.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001411.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002118.mp3 with noise 1-31836-B-4.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002118.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003206.mp3 with noise 4-161303-A-5.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003206.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003560.mp3 with noise 1-20736-A-18.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003560.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001377.mp3 with noise 4-165845-B-45.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001377.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001363.mp3 with noise 1-12653-A-15.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001363.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003574.mp3 with noise 1-58277-A-3.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003574.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003212.mp3 with noise 5-253085-A-3.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003212.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001405.mp3 with noise 1-53467-A-47.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001405.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002681.mp3 with noise 1-32373-A-35.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002681.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002859.mp3 with noise 5-243459-B-14.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002859.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001388.mp3 with noise 5-250026-B-30.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001388.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002695.mp3 with noise 4-164661-B-12.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002695.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002865.mp3 with noise 5-259514-A-26.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002865.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002871.mp3 with noise 1-28808-A-43.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002871.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002440.mp3 with noise 4-165791-B-45.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002440.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003986.mp3 with noise 1-27724-A-1.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003986.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001149.mp3 with noise 1-137-A-32.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001149.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003038.mp3 with noise 1-60997-B-20.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003038.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002326.mp3 with noise 1-57795-A-8.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002326.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002332.mp3 with noise 1-39937-A-28.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002332.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002454.mp3 with noise 4-149940-B-5.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002454.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003992.mp3 with noise 1-54918-B-14.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003992.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001175.mp3 with noise 1-32373-A-35.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001175.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003762.mp3 with noise 4-156993-A-19.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003762.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003004.mp3 with noise 4-161127-A-10.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003004.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001613.mp3 with noise 4-169127-A-41.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001613.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001607.mp3 with noise 3-203374-A-39.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001607.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003010.mp3 with noise 5-251489-A-24.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003010.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002468.mp3 with noise 1-43382-A-1.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002468.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003776.mp3 with noise 4-160036-A-33.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003776.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001161.mp3 with noise 1-9887-A-49.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001161.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002483.mp3 with noise 5-243635-A-29.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002483.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003945.mp3 with noise 4-167063-C-11.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003945.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001834.mp3 with noise 1-63871-A-10.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001834.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001820.mp3 with noise 5-257349-A-15.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001820.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003789.mp3 with noise 1-22882-A-44.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003789.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002497.mp3 with noise 4-165823-B-41.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002497.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003951.mp3 with noise 1-54958-A-10.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003951.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003979.mp3 with noise 4-163264-A-10.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003979.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001808.mp3 with noise 3-203377-A-39.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001808.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001836.mp3 with noise 1-51170-A-18.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001836.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003947.mp3 with noise 1-31482-B-42.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003947.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002481.mp3 with noise 1-23222-A-19.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002481.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001188.mp3 with noise 1-39901-B-11.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001188.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003953.mp3 with noise 1-40154-A-46.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003953.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002495.mp3 with noise 4-165823-B-41.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002495.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001822.mp3 with noise 5-260433-A-39.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001822.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001611.mp3 with noise 1-49098-A-35.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001611.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002318.mp3 with noise 5-250026-A-30.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002318.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003006.mp3 with noise 5-253101-A-49.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003006.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003760.mp3 with noise 1-28135-A-11.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003760.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001177.mp3 with noise 5-251971-A-47.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001177.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001163.mp3 with noise 5-253094-C-49.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001163.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003774.mp3 with noise 5-249937-A-22.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003774.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003012.mp3 with noise 4-159609-B-14.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003012.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001605.mp3 with noise 1-17742-A-12.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001605.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002324.mp3 with noise 4-167063-A-11.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002324.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003984.mp3 with noise 1-43764-A-34.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003984.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002442.mp3 with noise 5-263491-A-25.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002442.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003748.mp3 with noise 1-19118-A-24.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003748.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003990.mp3 with noise 1-29680-A-21.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003990.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002456.mp3 with noise 1-30344-A-0.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002456.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001639.mp3 with noise 5-250753-A-34.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001639.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002330.mp3 with noise 4-168155-A-15.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002330.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002867.mp3 with noise 1-50455-A-44.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002867.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002873.mp3 with noise 1-47923-A-28.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002873.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002683.mp3 with noise 4-157611-A-41.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002683.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003589.mp3 with noise 5-245040-A-35.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003589.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002697.mp3 with noise 5-256452-A-5.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002697.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001375.mp3 with noise 5-259169-A-5.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001375.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003562.mp3 with noise 1-9886-A-49.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003562.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003204.mp3 with noise 1-43764-A-34.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003204.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001413.mp3 with noise 5-261433-A-15.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001413.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001407.mp3 with noise 5-243773-B-44.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001407.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003210.mp3 with noise 1-28135-B-11.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003210.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002668.mp3 with noise 5-253085-B-3.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002668.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003576.mp3 with noise 1-30709-B-23.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003576.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001361.mp3 with noise 1-54065-A-45.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001361.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002640.mp3 with noise 1-43807-A-47.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002640.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002898.mp3 with noise 1-56270-A-29.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002898.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001349.mp3 with noise 4-154405-B-27.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001349.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003238.mp3 with noise 1-9886-A-49.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003238.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002126.mp3 with noise 5-244327-A-34.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002126.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002132.mp3 with noise 1-54918-A-14.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002132.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002654.mp3 with noise 4-154405-A-27.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002654.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002913.mp3 with noise 1-48298-A-46.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002913.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002907.mp3 with noise 1-29561-A-10.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002907.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002091.mp3 with noise 1-46938-B-7.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002091.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001598.mp3 with noise 3-197408-A-8.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001598.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002085.mp3 with noise 1-52290-A-30.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002085.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001201.mp3 with noise 1-17742-A-12.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001201.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003416.mp3 with noise 1-62509-A-45.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003416.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002708.mp3 with noise 1-46040-A-14.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002708.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003370.mp3 with noise 1-52323-A-24.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003370.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001567.mp3 with noise 4-167571-A-26.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001567.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001573.mp3 with noise 1-57316-A-13.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001573.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003364.mp3 with noise 1-34853-A-37.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003364.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003402.mp3 with noise 1-25777-A-48.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003402.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001215.mp3 with noise 1-21896-A-35.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001215.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002734.mp3 with noise 1-43807-B-47.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002734.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002052.mp3 with noise 1-46938-B-7.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002052.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002046.mp3 with noise 1-18074-B-6.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002046.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003358.mp3 with noise 5-250629-A-37.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003358.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001229.mp3 with noise 1-17742-A-12.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001229.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002720.mp3 with noise 1-36164-B-26.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002720.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001942.mp3 with noise 1-19840-A-36.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001942.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002293.mp3 with noise 1-62594-A-32.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002293.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003833.mp3 with noise 1-52323-A-24.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003833.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003827.mp3 with noise 5-253534-A-26.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003827.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002287.mp3 with noise 1-32579-A-29.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002287.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003199.mp3 with noise 5-243459-B-14.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003199.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001956.mp3 with noise 1-35687-A-38.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001956.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001765.mp3 with noise 1-977-A-39.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001765.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003172.mp3 with noise 4-168155-A-15.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003172.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003614.mp3 with noise 1-36400-A-23.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003614.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001003.mp3 with noise 1-19118-A-24.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001003.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001017.mp3 with noise 1-21189-A-10.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001017.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003600.mp3 with noise 5-249937-A-22.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003600.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003166.mp3 with noise 1-1791-A-26.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003166.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002278.mp3 with noise 3-188726-A-35.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002278.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001771.mp3 with noise 1-57163-A-38.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001771.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002250.mp3 with noise 1-51805-B-33.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002250.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001759.mp3 with noise 1-43760-A-11.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001759.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001981.mp3 with noise 1-56907-A-46.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001981.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002536.mp3 with noise 1-5996-A-6.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002536.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003628.mp3 with noise 1-17808-A-12.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003628.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002522.mp3 with noise 1-23996-B-35.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002522.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001995.mp3 with noise 5-253094-C-49.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001995.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002244.mp3 with noise 1-27403-A-28.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002244.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002523.mp3 with noise 5-253534-A-26.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002523.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002245.mp3 with noise 1-30226-A-0.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002245.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001994.mp3 with noise 1-36164-B-26.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001994.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001980.mp3 with noise 5-253085-B-3.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001980.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001758.mp3 with noise 1-19872-B-36.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001758.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002251.mp3 with noise 1-46040-A-14.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002251.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003629.mp3 with noise 5-250026-B-30.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003629.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002537.mp3 with noise 4-163606-A-16.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002537.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003601.mp3 with noise 1-56380-B-5.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003601.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001016.mp3 with noise 4-167063-C-11.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001016.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001770.mp3 with noise 4-164021-A-1.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001770.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002279.mp3 with noise 1-61221-A-17.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002279.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003167.mp3 with noise 5-260875-A-35.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003167.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003173.mp3 with noise 5-249748-A-28.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003173.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001764.mp3 with noise 1-47819-A-5.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001764.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001002.mp3 with noise 4-161303-B-5.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001002.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003615.mp3 with noise 4-159609-B-14.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003615.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003826.mp3 with noise 1-13572-A-46.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003826.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001957.mp3 with noise 1-137-A-32.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001957.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003198.mp3 with noise 1-48298-A-46.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003198.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002286.mp3 with noise 1-43807-C-47.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002286.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002292.mp3 with noise 1-57316-A-13.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002292.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001943.mp3 with noise 1-56380-B-5.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001943.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003832.mp3 with noise 1-54752-A-18.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003832.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003359.mp3 with noise 3-203373-A-39.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003359.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002047.mp3 with noise 1-51805-E-33.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002047.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002721.mp3 with noise 1-60460-A-36.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002721.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001228.mp3 with noise 5-251962-A-47.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001228.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002735.mp3 with noise 1-17124-A-43.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002735.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002053.mp3 with noise 4-163606-A-16.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002053.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003365.mp3 with noise 1-58277-A-3.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003365.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001572.mp3 with noise 5-248341-B-6.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001572.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001214.mp3 with noise 5-244526-A-26.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001214.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003403.mp3 with noise 4-161579-A-40.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003403.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002709.mp3 with noise 4-164661-B-12.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002709.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003417.mp3 with noise 1-23094-B-15.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003417.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001200.mp3 with noise 1-62849-A-38.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001200.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001566.mp3 with noise 1-19501-A-7.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001566.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003371.mp3 with noise 4-155650-B-24.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003371.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002084.mp3 with noise 5-257839-A-14.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002084.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001599.mp3 with noise 1-54084-A-42.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001599.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002090.mp3 with noise 4-161099-A-47.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002090.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002906.mp3 with noise 1-33658-A-26.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002906.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002912.mp3 with noise 1-28808-A-43.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002912.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002133.mp3 with noise 4-161099-B-47.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002133.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002655.mp3 with noise 1-51436-A-17.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002655.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001348.mp3 with noise 1-49409-A-8.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001348.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002899.mp3 with noise 4-168446-A-45.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002899.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002641.mp3 with noise 1-19501-A-7.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002641.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002127.mp3 with noise 1-27405-A-28.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002127.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003239.mp3 with noise 5-257349-A-15.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003239.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003211.mp3 with noise 1-34495-A-14.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003211.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001406.mp3 with noise 4-161127-A-10.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001406.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001360.mp3 with noise 1-67152-A-17.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001360.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003577.mp3 with noise 1-17565-A-12.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003577.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002669.mp3 with noise 4-165823-B-41.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002669.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003563.mp3 with noise 1-63871-A-10.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003563.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001374.mp3 with noise 5-243459-A-14.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001374.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001412.mp3 with noise 1-32373-A-35.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001412.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003205.mp3 with noise 1-31251-A-6.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003205.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002696.mp3 with noise 5-243635-A-29.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002696.mp3
# ...
# Processed FPTOpenSpeechData_Set001_V0.1_002263.mp3 with noise 1-31836-B-4.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002263.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003169.mp3 with noise 1-62850-A-38.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003169.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002277.mp3 with noise 5-251962-A-47.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002277.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002511.mp3 with noise 1-19118-A-24.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002511.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001018.mp3 with noise 4-163609-B-16.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001018.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002539.mp3 with noise 1-50661-A-44.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002539.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003627.mp3 with noise 1-51170-A-18.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003627.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001030.mp3 with noise 1-18074-A-6.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001030.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001756.mp3 with noise 1-39937-A-28.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001756.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003141.mp3 with noise 1-19872-A-36.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003141.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003155.mp3 with noise 1-36393-A-23.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003155.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001742.mp3 with noise 1-61212-A-32.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001742.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001024.mp3 with noise 3-188390-A-6.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001024.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003633.mp3 with noise 1-24796-A-47.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003633.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001743.mp3 with noise 1-63871-A-10.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001743.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003154.mp3 with noise 1-40730-A-1.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003154.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003632.mp3 with noise 5-261433-A-15.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003632.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001025.mp3 with noise 1-52290-A-30.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001025.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001031.mp3 with noise 1-46272-A-12.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001031.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003626.mp3 with noise 4-167155-A-32.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003626.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002538.mp3 with noise 1-51805-G-33.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002538.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003140.mp3 with noise 5-244310-A-25.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003140.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001757.mp3 with noise 4-163697-A-13.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001757.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002276.mp3 with noise 5-244315-B-6.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002276.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003168.mp3 with noise 1-64398-A-41.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003168.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001019.mp3 with noise 5-253094-D-49.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001019.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002510.mp3 with noise 1-47250-B-41.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002510.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002504.mp3 with noise 1-17970-A-4.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002504.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002262.mp3 with noise 1-18074-B-6.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002262.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003197.mp3 with noise 1-36400-A-23.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003197.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002289.mp3 with noise 4-163697-A-13.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002289.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001780.mp3 with noise 1-4211-A-12.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001780.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001958.mp3 with noise 1-54505-A-21.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001958.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003829.mp3 with noise 1-19872-A-36.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003829.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001794.mp3 with noise 1-54958-A-10.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001794.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003183.mp3 with noise 1-52290-A-30.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003183.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001964.mp3 with noise 4-167642-A-21.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001964.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003815.mp3 with noise 1-33658-A-26.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003815.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003801.mp3 with noise 5-253101-A-49.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003801.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001970.mp3 with noise 1-64473-A-45.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001970.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001227.mp3 with noise 1-47250-A-41.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001227.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003430.mp3 with noise 1-31482-B-42.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003430.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003356.mp3 with noise 1-57318-A-13.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003356.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002048.mp3 with noise 1-58277-A-3.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002048.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001541.mp3 with noise 3-188390-A-6.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001541.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001555.mp3 with noise 1-54752-A-18.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001555.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003342.mp3 with noise 5-263902-A-36.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003342.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003424.mp3 with noise 3-197408-A-8.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003424.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001233.mp3 with noise 1-51805-G-33.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001233.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002712.mp3 with noise 1-22804-A-46.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002712.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002074.mp3 with noise 5-256512-A-30.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002074.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002060.mp3 with noise 5-245040-A-35.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002060.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001569.mp3 with noise 4-156993-A-19.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001569.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002706.mp3 with noise 5-243773-A-44.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002706.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003418.mp3 with noise 1-51436-A-17.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003418.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002935.mp3 with noise 4-158653-A-32.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002935.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001582.mp3 with noise 1-28135-B-11.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001582.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003395.mp3 with noise 5-244933-A-34.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003395.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003381.mp3 with noise 4-158653-A-32.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003381.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001596.mp3 with noise 1-7974-B-49.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001596.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002921.mp3 with noise 1-57163-A-38.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002921.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002909.mp3 with noise 1-36929-A-47.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002909.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001353.mp3 with noise 3-197435-B-22.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001353.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002882.mp3 with noise 3-203375-A-39.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002882.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003544.mp3 with noise 1-19111-A-24.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003544.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003222.mp3 with noise 1-32579-A-29.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003222.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001435.mp3 with noise 4-161303-A-5.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001435.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001421.mp3 with noise 1-51035-A-16.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001421.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002128.mp3 with noise 1-50454-A-44.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002128.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003236.mp3 with noise 1-59102-A-13.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003236.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002896.mp3 with noise 4-164064-C-1.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002896.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003550.mp3 with noise 1-34119-A-1.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003550.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001347.mp3 with noise 1-47819-B-5.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001347.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003578.mp3 with noise 3-203373-A-39.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003578.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002666.mp3 with noise 1-16568-A-3.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002666.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001409.mp3 with noise 3-203375-A-39.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001409.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002100.mp3 with noise 1-21896-A-35.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002100.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002114.mp3 with noise 1-47714-A-16.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002114.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002672.mp3 with noise 1-18655-A-31.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002672.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002699.mp3 with noise 4-167155-A-32.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002699.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002841.mp3 with noise 1-7974-B-49.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002841.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003587.mp3 with noise 4-166661-A-10.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003587.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001390.mp3 with noise 3-197408-B-8.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001390.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001384.mp3 with noise 1-16746-A-15.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001384.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002855.mp3 with noise 1-38560-A-14.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002855.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003593.mp3 with noise 4-167063-C-11.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003593.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002869.mp3 with noise 1-56380-B-5.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002869.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001637.mp3 with noise 5-244178-A-32.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001637.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003020.mp3 with noise 1-26806-A-1.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003020.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002458.mp3 with noise 1-9841-A-13.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002458.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003746.mp3 with noise 1-17808-B-12.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003746.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001151.mp3 with noise 1-13613-A-37.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001151.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001145.mp3 with noise 4-167571-A-26.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001145.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003752.mp3 with noise 1-54752-A-18.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003752.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003034.mp3 with noise 4-156227-A-9.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003034.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001623.mp3 with noise 1-19118-A-24.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001623.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002302.mp3 with noise 3-187710-A-11.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002302.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002464.mp3 with noise 1-14262-A-37.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002464.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002470.mp3 with noise 1-46938-A-7.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002470.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001179.mp3 with noise 1-9841-A-13.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001179.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003008.mp3 with noise 4-152995-A-24.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003008.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_002316.mp3 with noise 4-161103-A-47.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_002316.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001192.mp3 with noise 3-197408-A-8.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001192.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003785.mp3 with noise 1-24524-B-19.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003785.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003791.mp3 with noise 4-167077-B-20.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003791.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003949.mp3 with noise 5-253085-B-3.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003949.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001186.mp3 with noise 1-36164-B-26.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001186.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001838.mp3 with noise 3-203377-A-39.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001838.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001810.mp3 with noise 1-65483-A-13.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001810.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003961.mp3 with noise 1-23706-A-49.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003961.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_003975.mp3 with noise 1-9841-A-13.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_003975.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_001804.mp3 with noise 1-60460-A-36.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_001804.mp3
