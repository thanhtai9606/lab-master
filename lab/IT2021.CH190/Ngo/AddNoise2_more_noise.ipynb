# %%
# pip install pydub

# %%
import os
import random
import numpy as np
from pydub import AudioSegment
from pydub.generators import WhiteNoise

# PinkNoise và BrownNoise không hỗ trợ trong pydub mặc định, tạo giả lập bằng cách lọc white noise

def generate_pink_noise(duration_ms):
    white = WhiteNoise().to_audio_segment(duration=duration_ms)
    return white.low_pass_filter(2000)  # Giả lập pink noise bằng lọc tần số thấp

def generate_brown_noise(duration_ms):
    white = WhiteNoise().to_audio_segment(duration=duration_ms)
    return white.low_pass_filter(500)  # Giả lập brown noise bằng lọc tần số thấp mạnh hơn

def generate_random_noise(duration_ms, noise_type="white"):
    """
    Sinh noise ngẫu nhiên dựa trên loại noise và độ dài.
    
    :param duration_ms: Độ dài của noise cần tạo (ms).
    :param noise_type: Loại noise (white, pink, brown).
    :return: AudioSegment chứa noise.
    """
    if noise_type == "white":
        return WhiteNoise().to_audio_segment(duration=duration_ms)
    elif noise_type == "pink":
        return generate_pink_noise(duration_ms)
    elif noise_type == "brown":
        return generate_brown_noise(duration_ms)
    else:
        return WhiteNoise().to_audio_segment(duration=duration_ms)  # Mặc định white noise

def add_noise_to_audio(original_audio_path, noise_audio_path, output_path):
    """
    Thêm nhiễu vào file audio gốc, gồm noise ngẫu nhiên và noise từ file nhỏ.
    Lưu file kết quả vào folder mới, không ghi đè.

    :param original_audio_path: Đường dẫn đến file audio gốc (mp3).
    :param noise_audio_path: Đường dẫn đến file audio nhiễu (wav).
    :param output_path: Đường dẫn lưu file kết quả (mp3).
    """
    # Load audio gốc và noise từ file nhỏ
    original_audio = AudioSegment.from_mp3(original_audio_path)
    noise_file_audio = AudioSegment.from_wav(noise_audio_path)

    # Sinh noise ngẫu nhiên với độ dài khớp audio gốc
    noise_type = random.choice(["white", "pink", "brown"])
    random_noise = generate_random_noise(len(original_audio), noise_type=noise_type)

    # Ghép noise từ file nhỏ để đủ dài
    if len(noise_file_audio) < len(original_audio):
        noise_file_audio = noise_file_audio * (len(original_audio) // len(noise_file_audio) + 1)
    noise_file_audio = noise_file_audio[:len(original_audio)]

    # Điều chỉnh âm lượng nhiễu nhỏ hơn âm gốc 1/4
    original_rms = original_audio.rms

    for noise_audio in [random_noise, noise_file_audio]:
        noise_rms = noise_audio.rms
        if noise_rms > 0:
            gain_db = 20 * np.log10(original_rms / 4 / noise_rms)
            noise_audio = noise_audio.apply_gain(gain_db)
        # Trộn vào original
        original_audio = original_audio.overlay(noise_audio)

    # Lưu file kết quả vào output_path
    original_audio.export(output_path, format="mp3")

def process_audio_lists(original_audio_folder, noise_audio_folder, output_folder):
    """
    Thêm noise ngẫu nhiên và noise từ file nhỏ vào tất cả file mp3 gốc.
    Lưu kết quả vào folder mới, không ghi đè file gốc.

    :param original_audio_folder: Thư mục chứa audio gốc.
    :param noise_audio_folder: Thư mục chứa audio nhiễu nhỏ.
    :param output_folder: Thư mục để lưu file kết quả.
    """
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    original_files = [f for f in os.listdir(original_audio_folder) if f.endswith(".mp3")]
    noise_files = [f for f in os.listdir(noise_audio_folder) if f.endswith(".wav")]

    for original_file in original_files:
        original_path = os.path.join(original_audio_folder, original_file)
        noise_file = random.choice(noise_files)
        noise_path = os.path.join(noise_audio_folder, noise_file)

        output_path = os.path.join(output_folder, original_file)
        add_noise_to_audio(original_path, noise_path, output_path)
        print(f"Processed {original_file} with noise {noise_file} -> {output_path}")

# Ví dụ sử dụng:
# process_audio_lists("path_to_original_audio", "path_to_noise_audio", "path_to_output_folder")

# %%
process_audio_lists("./SampleAudioClean/data", "./SampleAudioClean/noise", "./add_noise_output")
# Out:
# Processed FPTOpenSpeechData_Set001_V0.1_000925.mp3 with noise 1-43382-A-1.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000925.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000151.mp3 with noise 1-63871-A-10.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000151.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000718.mp3 with noise 1-51436-A-17.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000718.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000394.mp3 with noise 5-252248-A-34.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000394.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000493.mp3 with noise 4-152995-A-24.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000493.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000237.mp3 with noise 1-17092-B-27.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000237.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000859.mp3 with noise 1-39901-A-11.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000859.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000748.mp3 with noise 4-155650-A-24.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000748.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000549.mp3 with noise 1-48298-A-46.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000549.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000627.mp3 with noise 1-53467-A-47.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000627.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000104.mp3 with noise 1-23094-B-15.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000104.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000786.mp3 with noise 1-44831-A-1.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000786.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000906.mp3 with noise 5-259514-A-26.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000906.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000829.mp3 with noise 1-17808-A-12.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000829.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000521.mp3 with noise 1-67432-A-27.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000521.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000865.mp3 with noise 1-18655-A-31.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000865.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000251.mp3 with noise 1-15689-B-4.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000251.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000904.mp3 with noise 1-18757-A-4.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000904.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000772.mp3 with noise 1-18074-A-6.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000772.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000192.mp3 with noise 5-253534-A-26.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000192.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000998.mp3 with noise 4-163264-A-10.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000998.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000671.mp3 with noise 1-7456-A-13.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000671.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000561.mp3 with noise 1-30214-A-18.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000561.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000902.mp3 with noise 5-260432-A-39.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000902.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000415.mp3 with noise 1-19118-A-24.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000415.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000313.mp3 with noise 1-53444-A-28.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000313.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000474.mp3 with noise 1-67230-A-29.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000474.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000933.mp3 with noise 3-187549-A-6.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000933.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000456.mp3 with noise 1-9841-A-13.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000456.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000070.mp3 with noise 1-7974-A-49.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000070.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000836.mp3 with noise 1-33658-A-26.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000836.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000359.mp3 with noise 5-260011-A-34.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000359.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000404.mp3 with noise 1-51037-A-16.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000404.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000869.mp3 with noise 1-17585-A-7.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000869.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000834.mp3 with noise 1-62594-A-32.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000834.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000210.mp3 with noise 1-47273-A-21.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000210.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000110.mp3 with noise 1-32579-A-29.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000110.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000001.mp3 with noise 1-34094-A-5.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000001.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000983.mp3 with noise 1-54918-B-14.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000983.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000787.mp3 with noise 5-253094-C-49.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000787.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000482.mp3 with noise 1-17742-A-12.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000482.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000898.mp3 with noise 1-39937-A-28.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000898.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000249.mp3 with noise 1-51805-F-33.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000249.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000371.mp3 with noise 1-30214-A-18.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000371.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000980.mp3 with noise 4-169127-B-41.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000980.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000175.mp3 with noise 5-253094-C-49.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000175.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000146.mp3 with noise 4-157296-A-24.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000146.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000809.mp3 with noise 5-263490-A-25.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000809.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000398.mp3 with noise 3-203375-A-39.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000398.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000642.mp3 with noise 1-53501-A-32.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000642.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000699.mp3 with noise 4-163609-A-16.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000699.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000970.mp3 with noise 1-62509-A-45.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000970.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000017.mp3 with noise 1-29680-A-21.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000017.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000182.mp3 with noise 1-57163-A-38.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000182.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000827.mp3 with noise 5-253101-A-49.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000827.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000995.mp3 with noise 1-46938-A-7.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000995.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000685.mp3 with noise 3-197435-B-22.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000685.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000184.mp3 with noise 1-24524-B-19.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000184.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000824.mp3 with noise 5-262641-A-15.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000824.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000589.mp3 with noise 4-156844-A-21.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000589.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000386.mp3 with noise 1-50688-A-17.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000386.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000260.mp3 with noise 1-58923-A-27.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000260.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000483.mp3 with noise 1-51433-A-17.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000483.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000799.mp3 with noise 5-253094-A-49.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000799.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000510.mp3 with noise 5-243459-B-14.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000510.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000161.mp3 with noise 1-47819-B-5.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000161.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000844.mp3 with noise 1-47923-A-28.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000844.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_000558.mp3 with noise 1-58277-A-3.wav -> ./add_noise_output/FPTOpenSpeechData_Set001_V0.1_000558.mp3
# Processed FPTOpenSpeechData_Set001_V0.1_