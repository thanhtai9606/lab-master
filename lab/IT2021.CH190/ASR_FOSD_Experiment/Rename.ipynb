# %%
import os

def rename_audio_files(folder_path):
    for filename in os.listdir(folder_path):
        if filename.endswith(".mp3") and "_file_noise" in filename:
            new_filename = filename.replace("_file_noise", "")
            old_path = os.path.join(folder_path, filename)
            new_path = os.path.join(folder_path, new_filename)
            os.rename(old_path, new_path)
            print(f"Renamed: {filename} -> {new_filename}")

# Thư mục chứa các file audio
folder_path = "./NoiseFilteredData/data"
rename_audio_files(folder_path)
# Out:
# Renamed: FPTOpenSpeechData_Set001_V0.1_000226_file_noise.mp3 -> FPTOpenSpeechData_Set001_V0.1_000226.mp3
# Renamed: FPTOpenSpeechData_Set001_V0.1_000856_file_noise.mp3 -> FPTOpenSpeechData_Set001_V0.1_000856.mp3
# Renamed: FPTOpenSpeechData_Set001_V0.1_000605_file_noise.mp3 -> FPTOpenSpeechData_Set001_V0.1_000605.mp3
# Renamed: FPTOpenSpeechData_Set001_V0.1_000010_file_noise.mp3 -> FPTOpenSpeechData_Set001_V0.1_000010.mp3
# Renamed: FPTOpenSpeechData_Set001_V0.1_000459_file_noise.mp3 -> FPTOpenSpeechData_Set001_V0.1_000459.mp3
# Renamed: FPTOpenSpeechData_Set001_V0.1_000884_file_noise.mp3 -> FPTOpenSpeechData_Set001_V0.1_000884.mp3
# Renamed: FPTOpenSpeechData_Set001_V0.1_000449_file_noise.mp3 -> FPTOpenSpeechData_Set001_V0.1_000449.mp3
# Renamed: FPTOpenSpeechData_Set001_V0.1_000098_file_noise.mp3 -> FPTOpenSpeechData_Set001_V0.1_000098.mp3
# Renamed: FPTOpenSpeechData_Set001_V0.1_000400_file_noise.mp3 -> FPTOpenSpeechData_Set001_V0.1_000400.mp3
# ...
